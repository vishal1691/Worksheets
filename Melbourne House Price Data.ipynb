# %%
import pandas as pd
import numpy as np

# %%
df_house = pd.read_csv("data.csv")
df_house
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_house.shape
# Out:
# (23678, 21)

# %%
df_house.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df_house.isnull().sum()
# Out:
# Suburb             131
# Address            131
# Rooms              131
# Type               131
# Price             5282
# Method             131
# SellerG            131
# Date               131
# Distance           132
# Postcode           132
# Bedroom2          4612
# Bathroom          4615
# Car               4757
# Landsize          6268
# BuildingArea     13660
# YearBuilt        12138
# CouncilArea       8022
# Lattitude         4435
# Longtitude        4435
# Regionname         132
# Propertycount      132
# dtype: int64

# %% [markdown]
# Percentage of missing values column wise

# %%
df_house.isna().mean().round(4) * 100
# Out:
# Suburb            0.55
# Address           0.55
# Rooms             0.55
# Type              0.55
# Price            22.31
# Method            0.55
# SellerG           0.55
# Date              0.55
# Distance          0.56
# Postcode          0.56
# Bedroom2         19.48
# Bathroom         19.49
# Car              20.09
# Landsize         26.47
# BuildingArea     57.69
# YearBuilt        51.26
# CouncilArea      33.88
# Lattitude        18.73
# Longtitude       18.73
# Regionname        0.56
# Propertycount     0.56
# dtype: float64

# %%
df_house
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_house.isnull().any(axis = 1).sum()
# Out:
# 17482

# %%
len(df_house)
# Out:
# 23678

# %%
del df_house['BuildingArea']

# %%
del df_house['YearBuilt']

# %%
del df_house['CouncilArea']

# %%
df_house
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_house = df_house[df_house.isnull().sum(axis=1) < 5]

# %%
df_house
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23672  Williamstown        96 Verdon St    4.0    h  2500000.0     PI
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            4140
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2          160
# Bathroom          163
# Car               305
# Landsize         1816
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df_house
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23672  Williamstown        96 Verdon St    4.0    h  2500000.0     PI
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_house['Bedroom2'].fillna((df_house['Price'].mean()), inplace=True)
# Out:
# /Users/vishaln/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
df_house
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23672  Williamstown        96 Verdon St    4.0    h  2500000.0     PI
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            4140
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom          163
# Car               305
# Landsize         1816
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df_house['Car'].fillna((df_house['Price'].mean()), inplace=True)

# %%
df_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            4140
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom          163
# Car                 0
# Landsize         1816
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df_house.shape
# Out:
# (19226, 18)

# %% [markdown]
# Percentage of missing values still left column wise

# %%
df_house.isna().mean().round(4) * 100
# Out:
# Suburb            0.00
# Address           0.00
# Rooms             0.00
# Type              0.00
# Price            21.53
# Method            0.00
# SellerG           0.00
# Date              0.00
# Distance          0.00
# Postcode          0.00
# Bedroom2          0.00
# Bathroom          0.85
# Car               0.00
# Landsize          9.45
# Lattitude         0.14
# Longtitude        0.14
# Regionname        0.00
# Propertycount     0.00
# dtype: float64

# %%
df_house['Price'].fillna((df_house['Price'].mean()), inplace=True)

# %% [markdown]
# Explanation to treat missing values in target variable -  I have imputed the NaN in target variable with mean value so that
# the NaN values are treated in the appropriate manner.

# %%
df_house.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom          163
# Car                 0
# Landsize         1816
# Lattitude          26
# Longtitude         26
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df_house['Bathroom'].fillna((df_house['Price'].mean()), inplace=True)

# %%
df_house['Landsize'].fillna((df_house['Price'].mean()), inplace=True)

# %%
df_house['Lattitude'].fillna((df_house['Price'].mean()), inplace=True)

# %%
df_house['Longtitude'].fillna((df_house['Price'].mean()), inplace=True)

# %%
df_house.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df_house.shape
# Out:
# (19226, 18)

# %% [markdown]
# Percentage of rows removed = 23678 - 19226 = 4452 / 23678 = 18.8%

# %% [markdown]
# Percentage of columns removed = 21 - 18 = 3 / 21 = 14.2%

# %% [markdown]
# Justification for row removal - I have removed almost 18.8% rows in order to completely clear all the missing values in the date.
# There are so many missing values in the dataset which essentially need to be cleaned.
